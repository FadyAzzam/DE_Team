# %%
# prompt: mount gdrive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

def load_csvs(file_paths):
    dataframes = []
    for path in file_paths:
        try:
            df = pd.read_csv(path)
            dataframes.append(df)
            print(f"Loaded {path} successfully.")
        except FileNotFoundError:
            print(f"File {path} not found.")
        except Exception as e:
            print(f"An error occurred while loading {path}: {e}")
    return dataframes

# if __name__ == "__main__":
#     # List of file paths
#     file_paths = [r"C:\Users\paude\Documents\00. Backup 2023\EXTERIOR\MASTER\MA IAAC\03. Cursada\01. Modulo 03\S01 DE\Class Project\DE_Team\Scraped_csvs\data_cost.csv",
#                   r"C:\Users\paude\Documents\00. Backup 2023\EXTERIOR\MASTER\MA IAAC\03. Cursada\01. Modulo 03\S01 DE\Class Project\DE_Team\Scraped_csvs\data_prop_price.csv",
#                 r"C:\Users\paude\Documents\00. Backup 2023\EXTERIOR\MASTER\MA IAAC\03. Cursada\01. Modulo 03\S01 DE\Class Project\DE_Team\Scraped_csvs\data_qual.csv"
#                 ]


if __name__ == "__main__":
    # List of file paths
    file_paths = ["/content/drive/MyDrive/Colab Notebooks/DE/Project/Scraped_csvs/data_cost.csv",
                  "/content/drive/MyDrive/Colab Notebooks/DE/Project/Scraped_csvs/data_prop_price.csv",
                "/content/drive/MyDrive/Colab Notebooks/DE/Project/Scraped_csvs/data_qual.csv"
                ]


    # Load CSV files into dataframes
    dfs = load_csvs(file_paths)
# Out:
# Loaded /content/drive/MyDrive/Colab Notebooks/DE/Project/Scraped_csvs/data_cost.csv successfully.
# Loaded /content/drive/MyDrive/Colab Notebooks/DE/Project/Scraped_csvs/data_prop_price.csv successfully.
# Loaded /content/drive/MyDrive/Colab Notebooks/DE/Project/Scraped_csvs/data_qual.csv successfully.

# %%
dfs[0]
# Out:
#      Rank                   City  Cost of Living Index  Rent Index  \
# 0       1      Hamilton, Bermuda                 137.4        94.7
# 1       2     Basel, Switzerland                 120.2        46.6
# 2       3    Zurich, Switzerland                 118.3        64.4
# 3       4  Lausanne, Switzerland                 117.7        46.4
# 4       5      Bern, Switzerland                 110.5        42.3
# ..    ...                    ...                   ...         ...
# 365   366           Kochi, India                  20.6         6.6
# 366   367      Coimbatore, India                  20.4         4.0
# 367   368    Islamabad, Pakistan                  20.3         4.7
# 368   369       Lahore, Pakistan                  19.7         3.3
# 369   370      Karachi, Pakistan                  19.3         3.0
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                             117.2            147.7                   131.3
# 1                              85.3            135.7                   106.7
# 2                              92.7            121.0                   109.0
# 3                              83.9            123.3                   106.2
# 4                              78.2            108.3                    96.5
# ..                              ...              ...                     ...
# 365                            14.0             23.1                    10.7
# 366                            12.6             23.8                    11.0
# 367                            12.9             18.1                    14.1
# 368                            11.9             16.5                    15.1
# 369                            11.6             17.4                    12.2
#
#      Local Purchasing Power Index
# 0                            82.3
# 1                           133.5
# 2                           132.7
# 3                           106.7
# 4                           130.7
# ..                            ...
# 365                          60.7
# 366                          42.5
# 367                          24.7
# 368                          26.3
# 369                          23.8
#
# [370 rows x 8 columns]

# %%
dfs[1]
# Out:
#      Rank                             City  Price To Income Ratio  \
# 0       1            Addis Ababa, Ethiopia                   51.6
# 1       2                 Douala, Cameroon                   48.3
# 2       3                  Shanghai, China                   43.5
# 3       4               Colombo, Sri Lanka                   39.1
# 4       5                     Tehran, Iran                   39.1
# ..    ...                              ...                    ...
# 261   262   Saint Louis, MO, United States                    2.1
# 262   263       Memphis, TN, United States                    1.8
# 263   264     Milwaukee, WI, United States                    1.8
# 264   265  Indianapolis, IN, United States                    1.5
# 265   266       Detroit, MI, United States                    1.2
#
#      Gross Rental Yield City Centre  Gross Rental Yield Outside of Centre  \
# 0                               6.6                                   4.8
# 1                              10.3                                  13.0
# 2                               1.6                                   1.5
# 3                               4.2                                   2.1
# 4                               4.4                                   5.0
# ..                              ...                                   ...
# 261                            13.0                                  13.0
# 262                            15.9                                  15.6
# 263                            19.7                                  16.4
# 264                            19.4                                  16.6
# 265                            32.9                                  21.8
#
#      Price To Rent Ratio City Centre  \
# 0                               15.2
# 1                                9.7
# 2                               62.6
# 3                               23.7
# 4                               22.5
# ..                               ...
# 261                              7.7
# 262                              6.3
# 263                              5.1
# 264                              5.2
# 265                              3.0
#
#      Price To Rent Ratio Outside Of City Centre  \
# 0                                          20.7
# 1                                           7.7
# 2                                          65.8
# 3                                          47.3
# 4                                          20.1
# ..                                          ...
# 261                                         7.7
# 262                                         6.4
# 263                                         6.1
# 264                                         6.0
# 265                                         4.6
#
#      Mortgage As A Percentage Of Income  Affordability Index
# 0                                 861.5                  0.1
# 1                                 948.9                  0.1
# 2                                 337.0                  0.3
# 3                                 788.5                  0.1
# 4                                 933.2                  0.1
# ..                                  ...                  ...
# 261                                19.0                  5.3
# 262                                16.6                  6.0
# 263                                16.4                  6.1
# 264                                13.7                  7.3
# 265                                11.0                  9.1
#
# [266 rows x 9 columns]

# %%
dfs[2]
# Out:
#      Rank                               City  Quality of Life Index  \
# 0       1  The Hague (Den Haag), Netherlands                  224.1
# 1       2             Luxembourg, Luxembourg                  221.3
# 2       3             Eindhoven, Netherlands                  214.3
# 3       4             Rotterdam, Netherlands                  214.1
# 4       5                    Valencia, Spain                  202.5
# ..    ...                                ...                    ...
# 194   195                 Caracas, Venezuela                   64.4
# 195   196                  Dhaka, Bangladesh                   61.1
# 196   197                Manila, Philippines                   53.7
# 197   198                       Tehran, Iran                   53.3
# 198   199                     Lagos, Nigeria                   44.4
#
#      Purchasing Power Index  Safety Index  Health Care Index  \
# 0                     138.9          79.9               80.6
# 1                     171.5          71.1               78.2
# 2                     133.3          77.8               78.3
# 3                     140.6          71.7               80.6
# 4                      98.7          72.8               80.6
# ..                      ...           ...                ...
# 194                    11.7          18.1               38.1
# 195                    32.1          37.4               40.2
# 196                    33.6          35.3               62.5
# 197                    20.6          43.2               53.2
# 198                    12.2          31.7               47.5
#
#      Cost of Living Index  Property Price to Income Ratio  \
# 0                    58.1                             5.7
# 1                    60.9                             9.2
# 2                    61.2                             6.0
# 3                    59.2                             5.3
# 4                    46.3                             5.2
# ..                    ...                             ...
# 194                  41.5                            27.7
# 195                  24.8                            14.3
# 196                  36.0                            33.4
# 197                  28.4                            39.1
# 198                  34.6                            18.4
#
#      Traffic Commute Time Index  Pollution Index  Climate Index
# 0                          21.3             17.6           90.6
# 1                          26.6             19.6           82.6
# 2                          24.9             19.6           85.4
# 3                          23.4             24.7           87.9
# 4                          22.8             23.4           93.8
# ..                          ...              ...            ...
# 194                        33.7             73.9           99.9
# 195                        61.4             94.2           71.3
# 196                        51.7             89.8           61.2
# 197                        51.8             80.4           71.0
# 198                        68.8             89.0           60.8
#
# [199 rows x 11 columns]

# %%
merged_df = pd.merge(dfs[0], dfs[1], on='City', how='outer')
merged_df = pd.merge(merged_df, dfs[2], on='City', how='outer')

# %%
merged_df.head()
# print(merged_df)
# merged_df.shape
# Out:
#    Rank_x                   City  Cost of Living Index_x  Rent Index  \
# 0     1.0      Hamilton, Bermuda                   137.4        94.7
# 1     2.0     Basel, Switzerland                   120.2        46.6
# 2     3.0    Zurich, Switzerland                   118.3        64.4
# 3     4.0  Lausanne, Switzerland                   117.7        46.4
# 4     5.0      Bern, Switzerland                   110.5        42.3
#
#    Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                           117.2            147.7                   131.3
# 1                            85.3            135.7                   106.7
# 2                            92.7            121.0                   109.0
# 3                            83.9            123.3                   106.2
# 4                            78.2            108.3                    96.5
#
#    Local Purchasing Power Index  Rank_y  Price To Income Ratio  ...  Rank  \
# 0                          82.3     NaN                    NaN  ...   NaN
# 1                         133.5   111.0                   12.4  ...   NaN
# 2                         132.7    84.0                   14.0  ...   6.0
# 3                         106.7     NaN                    NaN  ...   NaN
# 4                         130.7   130.0                   11.4  ...   NaN
#
#    Quality of Life Index  Purchasing Power Index  Safety Index  \
# 0                    NaN                     NaN           NaN
# 1                    NaN                     NaN           NaN
# 2                  201.2                   165.7          77.3
# 3                    NaN                     NaN           NaN
# 4                    NaN                     NaN           NaN
#
#    Health Care Index  Cost of Living Index_y  Property Price to Income Ratio  \
# 0                NaN                     NaN                             NaN
# 1                NaN                     NaN                             NaN
# 2               69.9                   100.3                            14.0
# 3                NaN                     NaN                             NaN
# 4                NaN                     NaN                             NaN
#
#    Traffic Commute Time Index  Pollution Index  Climate Index
# 0                         NaN              NaN            NaN
# 1                         NaN              NaN            NaN
# 2                        38.9             23.0           81.5
# 3                         NaN              NaN            NaN
# 4                         NaN              NaN            NaN
#
# [5 rows x 26 columns]

# %%
merged_df.shape
# Out:
# (394, 26)

# %% [markdown]
# # Replacing NaNs

# %%
# prompt: Rename "City" to "City, Country_0", then create a new column in merged_df from the last string after the comma or (), then create a new column called City from the first string before the coma or () in City, Country

# Rename "City" to "City, Country_0"
merged_df.rename(columns={'City': 'City, Country_0'}, inplace=True)

# Create a new column from the last string after the comma or ()
merged_df['Country'] = merged_df['City, Country_0'].str.split(',').str[-1].str.split('(').str[0]

# Create a new column called City from the first string before the coma or ()
merged_df['City'] = merged_df['City, Country_0'].str.split(',').str[0].str.split('(').str[0]

# Print the first five rows of the merged_df DataFrame
merged_df.head()
# Out:
#    Rank_x        City, Country_0  Cost of Living Index_x  Rent Index  \
# 0     1.0      Hamilton, Bermuda                   137.4        94.7
# 1     2.0     Basel, Switzerland                   120.2        46.6
# 2     3.0    Zurich, Switzerland                   118.3        64.4
# 3     4.0  Lausanne, Switzerland                   117.7        46.4
# 4     5.0      Bern, Switzerland                   110.5        42.3
#
#    Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                           117.2            147.7                   131.3
# 1                            85.3            135.7                   106.7
# 2                            92.7            121.0                   109.0
# 3                            83.9            123.3                   106.2
# 4                            78.2            108.3                    96.5
#
#    Local Purchasing Power Index  Rank_y  Price To Income Ratio  ...  \
# 0                          82.3     NaN                    NaN  ...
# 1                         133.5   111.0                   12.4  ...
# 2                         132.7    84.0                   14.0  ...
# 3                         106.7     NaN                    NaN  ...
# 4                         130.7   130.0                   11.4  ...
#
#    Purchasing Power Index  Safety Index  Health Care Index  \
# 0                     NaN           NaN                NaN
# 1                     NaN           NaN                NaN
# 2                   165.7          77.3               69.9
# 3                     NaN           NaN                NaN
# 4                     NaN           NaN                NaN
#
#    Cost of Living Index_y  Property Price to Income Ratio  \
# 0                     NaN                             NaN
# 1                     NaN                             NaN
# 2                   100.3                            14.0
# 3                     NaN                             NaN
# 4                     NaN                             NaN
#
#    Traffic Commute Time Index  Pollution Index  Climate Index       Country  \
# 0                         NaN              NaN            NaN       Bermuda
# 1                         NaN              NaN            NaN   Switzerland
# 2                        38.9             23.0           81.5   Switzerland
# 3                         NaN              NaN            NaN   Switzerland
# 4                         NaN              NaN            NaN   Switzerland
#
#        City
# 0  Hamilton
# 1     Basel
# 2    Zurich
# 3  Lausanne
# 4      Bern
#
# [5 rows x 28 columns]

# %%
# prompt: in merged_df concatenate City and Country as 'City, Country' and add it to a new column named 'City, Country'

merged_df['City, Country'] = merged_df['City'] + ',' + merged_df['Country']

merged_df.head()
# Out:
#    Rank_x        City, Country_0  Cost of Living Index_x  Rent Index  \
# 0     1.0      Hamilton, Bermuda                   137.4        94.7
# 1     2.0     Basel, Switzerland                   120.2        46.6
# 2     3.0    Zurich, Switzerland                   118.3        64.4
# 3     4.0  Lausanne, Switzerland                   117.7        46.4
# 4     5.0      Bern, Switzerland                   110.5        42.3
#
#    Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                           117.2            147.7                   131.3
# 1                            85.3            135.7                   106.7
# 2                            92.7            121.0                   109.0
# 3                            83.9            123.3                   106.2
# 4                            78.2            108.3                    96.5
#
#    Local Purchasing Power Index  Rank_y  Price To Income Ratio  ...  \
# 0                          82.3     NaN                    NaN  ...
# 1                         133.5   111.0                   12.4  ...
# 2                         132.7    84.0                   14.0  ...
# 3                         106.7     NaN                    NaN  ...
# 4                         130.7   130.0                   11.4  ...
#
#    Safety Index  Health Care Index  Cost of Living Index_y  \
# 0           NaN                NaN                     NaN
# 1           NaN                NaN                     NaN
# 2          77.3               69.9                   100.3
# 3           NaN                NaN                     NaN
# 4           NaN                NaN                     NaN
#
#    Property Price to Income Ratio  Traffic Commute Time Index  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                            14.0                        38.9
# 3                             NaN                         NaN
# 4                             NaN                         NaN
#
#    Pollution Index  Climate Index       Country      City  \
# 0              NaN            NaN       Bermuda  Hamilton
# 1              NaN            NaN   Switzerland     Basel
# 2             23.0           81.5   Switzerland    Zurich
# 3              NaN            NaN   Switzerland  Lausanne
# 4              NaN            NaN   Switzerland      Bern
#
#            City, Country
# 0      Hamilton, Bermuda
# 1     Basel, Switzerland
# 2    Zurich, Switzerland
# 3  Lausanne, Switzerland
# 4      Bern, Switzerland
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Rounding the numbers

# %%
# prompt: for numeric data only, replace the NaN's with the average values of the same columns who share a similar Country, change the data frame name to merged_filled1_ df, for numeric data only round the floats to one decimal number

# Create a copy of the dataframe
merged_filled1_df = merged_df.copy()

# Select numeric columns
numeric_columns = merged_filled1_df.select_dtypes(include=['float64', 'int64']).columns

# Group the dataframe by country and calculate the mean for each numeric column
country_means = merged_filled1_df.groupby('Country')[numeric_columns].mean().round(1)

# Replace NaN values in the numeric columns with the corresponding country mean
for col in numeric_columns:
    for country in country_means.index:
        merged_filled1_df.loc[(merged_filled1_df['Country'] == country) & (merged_filled1_df[col].isna()), col] = country_means.loc[country, col]

# Display the first few rows of the dataframe
merged_filled1_df.head()
# Out:
#    Rank_x        City, Country_0  Cost of Living Index_x  Rent Index  \
# 0     1.0      Hamilton, Bermuda                   137.4        94.7
# 1     2.0     Basel, Switzerland                   120.2        46.6
# 2     3.0    Zurich, Switzerland                   118.3        64.4
# 3     4.0  Lausanne, Switzerland                   117.7        46.4
# 4     5.0      Bern, Switzerland                   110.5        42.3
#
#    Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                           117.2            147.7                   131.3
# 1                            85.3            135.7                   106.7
# 2                            92.7            121.0                   109.0
# 3                            83.9            123.3                   106.2
# 4                            78.2            108.3                    96.5
#
#    Local Purchasing Power Index  Rank_y  Price To Income Ratio  ...  \
# 0                          82.3     NaN                    NaN  ...
# 1                         133.5   111.0                   12.4  ...
# 2                         132.7    84.0                   14.0  ...
# 3                         106.7   108.2                   12.6  ...
# 4                         130.7   130.0                   11.4  ...
#
#    Safety Index  Health Care Index  Cost of Living Index_y  \
# 0           NaN                NaN                     NaN
# 1          73.4               70.8                    99.8
# 2          77.3               69.9                   100.3
# 3          73.4               70.8                    99.8
# 4          73.4               70.8                    99.8
#
#    Property Price to Income Ratio  Traffic Commute Time Index  \
# 0                             NaN                         NaN
# 1                            13.4                        35.0
# 2                            14.0                        38.9
# 3                            13.4                        35.0
# 4                            13.4                        35.0
#
#    Pollution Index  Climate Index       Country      City  \
# 0              NaN            NaN       Bermuda  Hamilton
# 1             24.0           82.0   Switzerland     Basel
# 2             23.0           81.5   Switzerland    Zurich
# 3             24.0           82.0   Switzerland  Lausanne
# 4             24.0           82.0   Switzerland      Bern
#
#            City, Country
# 0      Hamilton, Bermuda
# 1     Basel, Switzerland
# 2    Zurich, Switzerland
# 3  Lausanne, Switzerland
# 4      Bern, Switzerland
#
# [5 rows x 29 columns]

# %%
# prompt: check merged_filled1_df for NaN's

merged_filled1_df.isnull().sum()
# Out:
# Rank_x                                         3
# City, Country_0                                0
# Cost of Living Index_x                         3
# Rent Index                                     3
# Cost of Living Plus Rent Index                 3
# Groceries Index                                3
# Restaurant Price Index                         3
# Local Purchasing Power Index                   3
# Rank_y                                        11
# Price To Income Ratio                         11
# Gross Rental Yield City Centre                11
# Gross Rental Yield Outside of Centre          11
# Price To Rent Ratio City Centre               11
# Price To Rent Ratio Outside Of City Centre    11
# Mortgage As A Percentage Of Income            11
# Affordability Index                           11
# Rank                                          29
# Quality of Life Index                         29
# Purchasing Power Index                        29
# Safety Index                                  29
# Health Care Index                             29
# Cost of Living Index_y                        29
# Property Price to Income Ratio                29
# Traffic Commute Time Index                    29
# Pollution Index                               29
# Climate Index                                 29
# Country                                        0
# City                                           0
# City, Country                                  0
# dtype: int64

# %%
# prompt: for numeric data only, replace the NaN's with the average values of the same columns, change the data frame name to merged_filled2_ df

# Create a copy of the dataframe
merged_filled2_df = merged_filled1_df.copy()

# Select numeric columns
numeric_columns = merged_filled2_df.select_dtypes(include=['float64', 'int64']).columns

# Calculate the average values for each numeric column
column_means = merged_filled2_df[numeric_columns].mean()

# Replace NaN values with the average values
merged_filled2_df[numeric_columns] = merged_filled2_df[numeric_columns].fillna(column_means)

# Display the first few rows of the dataframe
merged_filled2_df.head()
# Out:
#    Rank_x        City, Country_0  Cost of Living Index_x  Rent Index  \
# 0     1.0      Hamilton, Bermuda                   137.4        94.7
# 1     2.0     Basel, Switzerland                   120.2        46.6
# 2     3.0    Zurich, Switzerland                   118.3        64.4
# 3     4.0  Lausanne, Switzerland                   117.7        46.4
# 4     5.0      Bern, Switzerland                   110.5        42.3
#
#    Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                           117.2            147.7                   131.3
# 1                            85.3            135.7                   106.7
# 2                            92.7            121.0                   109.0
# 3                            83.9            123.3                   106.2
# 4                            78.2            108.3                    96.5
#
#    Local Purchasing Power Index      Rank_y  Price To Income Ratio  ...  \
# 0                          82.3  137.702611              12.135248  ...
# 1                         133.5  111.000000              12.400000  ...
# 2                         132.7   84.000000              14.000000  ...
# 3                         106.7  108.200000              12.600000  ...
# 4                         130.7  130.000000              11.400000  ...
#
#    Safety Index  Health Care Index  Cost of Living Index_y  \
# 0     57.853425          67.508493               53.478356
# 1     73.400000          70.800000               99.800000
# 2     77.300000          69.900000              100.300000
# 3     73.400000          70.800000               99.800000
# 4     73.400000          70.800000               99.800000
#
#    Property Price to Income Ratio  Traffic Commute Time Index  \
# 0                       12.152603                   36.078356
# 1                       13.400000                   35.000000
# 2                       14.000000                   38.900000
# 3                       13.400000                   35.000000
# 4                       13.400000                   35.000000
#
#    Pollution Index  Climate Index       Country      City  \
# 0        49.834521      77.721096       Bermuda  Hamilton
# 1        24.000000      82.000000   Switzerland     Basel
# 2        23.000000      81.500000   Switzerland    Zurich
# 3        24.000000      82.000000   Switzerland  Lausanne
# 4        24.000000      82.000000   Switzerland      Bern
#
#            City, Country
# 0      Hamilton, Bermuda
# 1     Basel, Switzerland
# 2    Zurich, Switzerland
# 3  Lausanne, Switzerland
# 4      Bern, Switzerland
#
# [5 rows x 29 columns]

# %%
merged_filled2_df.isnull().sum()
# Out:
# Rank_x                                        0
# City, Country_0                               0
# Cost of Living Index_x                        0
# Rent Index                                    0
# Cost of Living Plus Rent Index                0
# Groceries Index                               0
# Restaurant Price Index                        0
# Local Purchasing Power Index                  0
# Rank_y                                        0
# Price To Income Ratio                         0
# Gross Rental Yield City Centre                0
# Gross Rental Yield Outside of Centre          0
# Price To Rent Ratio City Centre               0
# Price To Rent Ratio Outside Of City Centre    0
# Mortgage As A Percentage Of Income            0
# Affordability Index                           0
# Rank                                          0
# Quality of Life Index                         0
# Purchasing Power Index                        0
# Safety Index                                  0
# Health Care Index                             0
# Cost of Living Index_y                        0
# Property Price to Income Ratio                0
# Traffic Commute Time Index                    0
# Pollution Index                               0
# Climate Index                                 0
# Country                                       0
# City                                          0
# City, Country                                 0
# dtype: int64

# %% [markdown]
# # Editing rows and columns to match the new dataset

# %%
# prompt: for numeric data only, round the data in all the merged_filled2_df to one decimal figure, then round the data in Rank_x and Rank_y to integers

import numpy as np

# Round numeric data to one decimal figure
for col in merged_filled2_df.select_dtypes(include=['float64', 'int64']):
    merged_filled2_df[col] = np.round(merged_filled2_df[col], 1)

# Round Rank_x and Rank_y to integers
merged_filled2_df['Rank_x'] = merged_filled2_df['Rank_x'].astype(int)
merged_filled2_df['Rank_y'] = merged_filled2_df['Rank_y'].astype(int)

# Display the first few rows of the dataframe
merged_filled2_df.head()
# Out:
#    Rank_x        City, Country_0  Cost of Living Index_x  Rent Index  \
# 0       1      Hamilton, Bermuda                   137.4        94.7
# 1       2     Basel, Switzerland                   120.2        46.6
# 2       3    Zurich, Switzerland                   118.3        64.4
# 3       4  Lausanne, Switzerland                   117.7        46.4
# 4       5      Bern, Switzerland                   110.5        42.3
#
#    Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                           117.2            147.7                   131.3
# 1                            85.3            135.7                   106.7
# 2                            92.7            121.0                   109.0
# 3                            83.9            123.3                   106.2
# 4                            78.2            108.3                    96.5
#
#    Local Purchasing Power Index  Rank_y  Price To Income Ratio  ...  \
# 0                          82.3     137                   12.1  ...
# 1                         133.5     111                   12.4  ...
# 2                         132.7      84                   14.0  ...
# 3                         106.7     108                   12.6  ...
# 4                         130.7     130                   11.4  ...
#
#    Safety Index  Health Care Index  Cost of Living Index_y  \
# 0          57.9               67.5                    53.5
# 1          73.4               70.8                    99.8
# 2          77.3               69.9                   100.3
# 3          73.4               70.8                    99.8
# 4          73.4               70.8                    99.8
#
#    Property Price to Income Ratio  Traffic Commute Time Index  \
# 0                            12.2                        36.1
# 1                            13.4                        35.0
# 2                            14.0                        38.9
# 3                            13.4                        35.0
# 4                            13.4                        35.0
#
#    Pollution Index  Climate Index       Country      City  \
# 0             49.8           77.7       Bermuda  Hamilton
# 1             24.0           82.0   Switzerland     Basel
# 2             23.0           81.5   Switzerland    Zurich
# 3             24.0           82.0   Switzerland  Lausanne
# 4             24.0           82.0   Switzerland      Bern
#
#            City, Country
# 0      Hamilton, Bermuda
# 1     Basel, Switzerland
# 2    Zurich, Switzerland
# 3  Lausanne, Switzerland
# 4      Bern, Switzerland
#
# [5 rows x 29 columns]

# %%
# sort data in merged_filled3_df by 'City, Country'

merged_filled3_df = merged_filled2_df.sort_values(by='City, Country', inplace=False)


merged_filled3_df.head()
# Out:
#      Rank_x                  City, Country_0  Cost of Living Index_x  \
# 155     156                  Aachen, Germany                    61.3
# 35       36                  Aarhus, Denmark                    77.0
# 122     123         Aberdeen, United Kingdom                    65.1
# 163     164  Abu Dhabi, United Arab Emirates                    59.3
# 344     345                     Accra, Ghana                    27.4
#
#      Rent Index  Cost of Living Plus Rent Index  Groceries Index  \
# 155        20.5                            42.0             56.7
# 35         29.8                            54.6             70.1
# 122        24.4                            45.8             56.1
# 163        46.8                            53.4             43.1
# 344        10.6                            19.4             29.0
#
#      Restaurant Price Index  Local Purchasing Power Index  Rank_y  \
# 155                    52.1                         110.7     156
# 35                     81.7                         103.9     199
# 122                    61.3                         113.8     135
# 163                    63.6                         105.9     213
# 344                    23.2                          14.3     137
#
#      Price To Income Ratio  ...  Safety Index  Health Care Index  \
# 155                   10.0  ...          61.7               74.8
# 35                     7.7  ...          74.4               77.0
# 122                   11.2  ...          50.0               74.8
# 163                    6.5  ...          88.1               71.0
# 344                   12.1  ...          57.9               67.5
#
#      Cost of Living Index_y  Property Price to Income Ratio  \
# 155                    63.6                             9.4
# 35                     74.7                             8.4
# 122                    65.8                             8.8
# 163                    54.5                             6.5
# 344                    53.5                            12.2
#
#      Traffic Commute Time Index  Pollution Index  Climate Index  \
# 155                        30.4             33.3           82.1
# 35                         27.7             21.1           83.7
# 122                        35.8             44.7           86.3
# 163                        31.7             46.6           43.9
# 344                        36.1             49.8           77.7
#
#                    Country       City                    City, Country
# 155                Germany     Aachen                  Aachen, Germany
# 35                 Denmark     Aarhus                  Aarhus, Denmark
# 122         United Kingdom   Aberdeen         Aberdeen, United Kingdom
# 163   United Arab Emirates  Abu Dhabi  Abu Dhabi, United Arab Emirates
# 344                  Ghana      Accra                     Accra, Ghana
#
# [5 rows x 29 columns]

# %%
# Save merged_filled2_df as a CSV file

merged_filled3_df.to_csv("/content/drive/MyDrive/Colab Notebooks/DE/Project/Modified_csvs/Merged_data_filled.csv", index=False)

# merged_filled3_df.to_csv(r"C:\Users\paude\Documents\00. Backup 2023\EXTERIOR\MASTER\MA IAAC\03. Cursada\01. Modulo 03\S01 DE\Class Project\DE_Team\Scraped_csvs\data_cost.csv", index=False)

# %% [markdown]
# #New Cities Dataframe

# %%
# read csv file "/content/drive/MyDrive/Colab Notebooks/DE/Project/Raw_csvs/worldcities.csv" from Gdrive

all_cities_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/DE/Project/Raw_csvs/worldcities.csv")

all_cities_df.head(10)
# Out:
#           City       Country      Lat       Lng iso2 iso3  Population  \
# 0        Tokyo         Japan  35.6897  139.6922   JP  JPN  37732000.0
# 1      Jakarta     Indonesia  -6.1750  106.8275   ID  IDN  33756000.0
# 2        Delhi         India  28.6100   77.2300   IN  IND  32226000.0
# 3    Guangzhou         China  23.1300  113.2600   CN  CHN  26940000.0
# 4       Mumbai         India  19.0761   72.8775   IN  IND  24973000.0
# 5       Manila   Philippines  14.5958  120.9772   PH  PHL  24922000.0
# 6     Shanghai         China  31.2286  121.4747   CN  CHN  24073000.0
# 7    Sao Paulo        Brazil -23.5500  -46.6333   BR  BRA  23086000.0
# 8        Seoul  Korea, South  37.5600  126.9900   KR  KOR  23016000.0
# 9  Mexico City        Mexico  19.4333  -99.1333   MX  MEX  21804000.0
#
#            ID
# 0  1392685764
# 1  1360771077
# 2  1356872604
# 3  1156237133
# 4  1356226629
# 5  1608618140
# 6  1156073548
# 7  1076532519
# 8  1410836482
# 9  1484247881

# %%
# prompt: in all_cities_df, concatenate City and Country as: 'City, Country' in a new column called 'City, Country'

all_cities_df['City, Country'] = all_cities_df['City'] + ', ' + all_cities_df['Country']

# prompt: sort all_cities_df by 'Population'

all_cities_df.sort_values(by='Population', inplace=True, ascending=False)

all_cities_df.head()
# Out:
#         City    Country      Lat       Lng iso2 iso3  Population          ID  \
# 0      Tokyo      Japan  35.6897  139.6922   JP  JPN  37732000.0  1392685764
# 1    Jakarta  Indonesia  -6.1750  106.8275   ID  IDN  33756000.0  1360771077
# 2      Delhi      India  28.6100   77.2300   IN  IND  32226000.0  1356872604
# 3  Guangzhou      China  23.1300  113.2600   CN  CHN  26940000.0  1156237133
# 4     Mumbai      India  19.0761   72.8775   IN  IND  24973000.0  1356226629
#
#         City, Country
# 0        Tokyo, Japan
# 1  Jakarta, Indonesia
# 2        Delhi, India
# 3    Guangzhou, China
# 4       Mumbai, India

# %%
all_cities_df.shape
# Out:
# (47868, 9)

# %%
# keep only the first 1000 rows in all_cities_df

# cities_1000_df = all_cities_df.head(1000)

# cities_1000_df.head(50)

# %%
# prompt: merge all_cities_df and merged_filled3_df on 'City, Country'

import pandas as pd
merged_cities_df = pd.merge(all_cities_df, merged_filled3_df, on='City, Country', how='outer')

# Display the first few rows of the dataframe
merged_cities_df.head(50)
# Out:
#               City_x         Country_x      Lat       Lng iso2 iso3  \
# 0              Tokyo             Japan  35.6897  139.6922   JP  JPN
# 1            Jakarta         Indonesia  -6.1750  106.8275   ID  IDN
# 2              Delhi             India  28.6100   77.2300   IN  IND
# 3          Guangzhou             China  23.1300  113.2600   CN  CHN
# 4             Mumbai             India  19.0761   72.8775   IN  IND
# 5             Manila       Philippines  14.5958  120.9772   PH  PHL
# 6           Shanghai             China  31.2286  121.4747   CN  CHN
# 7          Sao Paulo            Brazil -23.5500  -46.6333   BR  BRA
# 8              Seoul      Korea, South  37.5600  126.9900   KR  KOR
# 9        Mexico City            Mexico  19.4333  -99.1333   MX  MEX
# 10             Cairo             Egypt  30.0444   31.2358   EG  EGY
# 11          New York     United States  40.6943  -73.9249   US  USA
# 12             Dhaka        Bangladesh  23.7639   90.3889   BD  BGD
# 13           Beijing             China  39.9067  116.3975   CN  CHN
# 14           Kolkata             India  22.5675   88.3700   IN  IND
# 15           Bangkok          Thailand  13.7525  100.4942   TH  THA
# 16          Shenzhen             China  22.5415  114.0596   CN  CHN
# 17            Moscow            Russia  55.7558   37.6172   RU  RUS
# 18      Buenos Aires         Argentina -34.6033  -58.3817   AR  ARG
# 19             Lagos           Nigeria   6.4550    3.3841   NG  NGA
# 20          Istanbul            Turkey  41.0136   28.9550   TR  TUR
# 21           Karachi          Pakistan  24.8600   67.0100   PK  PAK
# 22         Bangalore             India  12.9789   77.5917   IN  IND
# 23  Ho Chi Minh City           Vietnam  10.7756  106.7019   VN  VNM
# 24             Osaka             Japan  34.6939  135.5022   JP  JPN
# 25           Chengdu             China  30.6600  104.0633   CN  CHN
# 26            Tehran              Iran  35.6892   51.3889   IR  IRN
# 27          Kinshasa  Congo (Kinshasa)  -4.3219   15.3119   CD  COD
# 28    Rio de Janeiro            Brazil -22.9111  -43.2056   BR  BRA
# 29           Chennai             India  13.0825   80.2750   IN  IND
# 30             Xi'an             China  34.2611  108.9422   CN  CHN
# 31            Lahore          Pakistan  31.5497   74.3436   PK  PAK
# 32         Chongqing             China  29.5637  106.5504   CN  CHN
# 33       Los Angeles     United States  34.1141 -118.4068   US  USA
# 34           Baoding             China  38.8740  115.4640   CN  CHN
# 35            London    United Kingdom  51.5072   -0.1275   GB  GBR
# 36             Paris            France  48.8567    2.3522   FR  FRA
# 37             Linyi             China  35.1038  118.3564   CN  CHN
# 38          Dongguan             China  23.0210  113.7520   CN  CHN
# 39          Dongguan             China  39.0140  111.0768   CN  CHN
# 40         Hyderabad             India  17.3617   78.4747   IN  IND
# 41           Tianjin             China  39.1336  117.2054   CN  CHN
# 42              Lima              Peru -12.0600  -77.0375   PE  PER
# 43             Wuhan             China  30.5934  114.3046   CN  CHN
# 44           Nanyang             China  32.9987  112.5292   CN  CHN
# 45          Hangzhou             China  30.2670  120.1530   CN  CHN
# 46            Foshan             China  23.0214  113.1216   CN  CHN
# 47            Nagoya             Japan  35.1833  136.9000   JP  JPN
# 48          Tongshan             China  34.2040  117.2840   CN  CHN
# 49            Luanda            Angola  -8.8383   13.2344   AO  AGO
#
#     Population            ID               City, Country  Rank_x  ...  \
# 0   37732000.0  1.392686e+09                Tokyo, Japan   169.0  ...
# 1   33756000.0  1.360771e+09          Jakarta, Indonesia   312.0  ...
# 2   32226000.0  1.356873e+09                Delhi, India   354.0  ...
# 3   26940000.0  1.156237e+09            Guangzhou, China   285.0  ...
# 4   24973000.0  1.356227e+09               Mumbai, India   351.0  ...
# 5   24922000.0  1.608618e+09         Manila, Philippines   262.0  ...
# 6   24073000.0  1.156074e+09             Shanghai, China   238.0  ...
# 7   23086000.0  1.076533e+09           Sao Paulo, Brazil   252.0  ...
# 8   23016000.0  1.410836e+09         Seoul, Korea, South     NaN  ...
# 9   21804000.0  1.484248e+09         Mexico City, Mexico   206.0  ...
# 10  20296000.0  1.818254e+09                Cairo, Egypt   324.0  ...
# 11  18908608.0  1.840034e+09     New York, United States     7.0  ...
# 12  18627000.0  1.050529e+09           Dhaka, Bangladesh   341.0  ...
# 13  18522000.0  1.156229e+09              Beijing, China   267.0  ...
# 14  18502000.0  1.356061e+09              Kolkata, India   364.0  ...
# 15  18007000.0  1.764069e+09           Bangkok, Thailand   235.0  ...
# 16  17619000.0  1.156159e+09             Shenzhen, China   269.0  ...
# 17  17332000.0  1.643318e+09              Moscow, Russia   280.0  ...
# 18  16710000.0  1.032717e+09     Buenos Aires, Argentina   344.0  ...
# 19  16637000.0  1.566594e+09              Lagos, Nigeria   362.0  ...
# 20  16079000.0  1.792756e+09            Istanbul, Turkey   270.0  ...
# 21  15738000.0  1.586129e+09           Karachi, Pakistan   370.0  ...
# 22  15386000.0  1.356410e+09            Bangalore, India   326.0  ...
# 23  15136000.0  1.704774e+09   Ho Chi Minh City, Vietnam   310.0  ...
# 24  15126000.0  1.392420e+09                Osaka, Japan   207.0  ...
# 25  14645000.0  1.156422e+09              Chengdu, China   315.0  ...
# 26  14148000.0  1.364305e+09                Tehran, Iran   323.0  ...
# 27  12836000.0  1.180000e+09  Kinshasa, Congo (Kinshasa)     NaN  ...
# 28  12592000.0  1.076888e+09      Rio de Janeiro, Brazil   258.0  ...
# 29  12395000.0  1.356375e+09              Chennai, India   358.0  ...
# 30  12328000.0  1.156244e+09                Xi'an, China     NaN  ...
# 31  12306000.0  1.586801e+09            Lahore, Pakistan   369.0  ...
# 32  12135000.0  1.156937e+09            Chongqing, China     NaN  ...
# 33  11922389.0  1.840020e+09  Los Angeles, United States    17.0  ...
# 34  11544036.0  1.156257e+09              Baoding, China     NaN  ...
# 35  11262000.0  1.826646e+09      London, United Kingdom    27.0  ...
# 36  11060000.0  1.250015e+09               Paris, France    46.0  ...
# 37  11018365.0  1.156086e+09                Linyi, China     NaN  ...
# 38  10646000.0  1.156478e+09             Dongguan, China     NaN  ...
# 39     75135.0  1.156887e+09             Dongguan, China     NaN  ...
# 40  10494000.0  1.356872e+09            Hyderabad, India   355.0  ...
# 41  10368000.0  1.156174e+09              Tianjin, China     NaN  ...
# 42  10320000.0  1.604729e+09                  Lima, Peru   292.0  ...
# 43  10251000.0  1.156117e+09                Wuhan, China   304.0  ...
# 44   9713112.0  1.156192e+09              Nanyang, China     NaN  ...
# 45   9523000.0  1.156275e+09             Hangzhou, China   281.0  ...
# 46   9498863.0  1.156738e+09               Foshan, China     NaN  ...
# 47   9197000.0  1.392407e+09               Nagoya, Japan     NaN  ...
# 48   9083790.0  1.156242e+09             Tongshan, China     NaN  ...
# 49   9051000.0  1.024950e+09              Luanda, Angola     NaN  ...
#
#    Purchasing Power Index  Safety Index  Health Care Index  \
# 0                   111.2          76.0               79.2
# 1                    43.4          47.3               56.9
# 2                   118.8          41.0               66.7
# 3                    90.2          72.5               66.6
# 4                    70.2          55.3               65.3
# 5                    33.6          35.3               62.5
# 6                    77.0          71.4               64.4
# 7                    30.8          29.6               59.9
# 8                     NaN           NaN                NaN
# 9                    39.4          32.2               65.9
# 10                   18.0          49.3               45.9
# 11                  100.0          49.3               62.7
# 12                   32.1          37.4               40.2
# 13                  103.3          73.6               68.8
# 14                   63.6          54.0               59.8
# 15                   39.0          60.2               76.7
# 16                   90.2          72.5               66.6
# 17                   71.6          64.1               67.1
# 18                   32.3          36.6               68.4
# 19                   12.2          31.7               47.5
# 20                   47.2          52.2               69.9
# 21                   27.1          43.6               56.5
# 22                  164.0          45.6               64.9
# 23                   36.0          47.9               61.1
# 24                  111.2          76.0               79.2
# 25                   90.2          72.5               66.6
# 26                   20.6          43.2               53.2
# 27                    NaN           NaN                NaN
# 28                   23.9          22.6               45.5
# 29                  101.9          60.1               69.4
# 30                    NaN           NaN                NaN
# 31                   29.7          63.6               62.3
# 32                    NaN           NaN                NaN
# 33                  126.0          47.0               61.1
# 34                    NaN           NaN                NaN
# 35                  101.2          45.4               70.0
# 36                   92.7          42.3               77.5
# 37                    NaN           NaN                NaN
# 38                    NaN           NaN                NaN
# 39                    NaN           NaN                NaN
# 40                  112.2          56.7               65.3
# 41                    NaN           NaN                NaN
# 42                   30.5          29.1               58.1
# 43                   90.2          72.5               66.6
# 44                    NaN           NaN                NaN
# 45                   90.2          72.5               66.6
# 46                    NaN           NaN                NaN
# 47                    NaN           NaN                NaN
# 48                    NaN           NaN                NaN
# 49                    NaN           NaN                NaN
#
#     Cost of Living Index_y  Property Price to Income Ratio  \
# 0                     53.6                            12.9
# 1                     30.0                            15.8
# 2                     23.4                             8.8
# 3                     36.4                            37.3
# 4                     23.8                            32.6
# 5                     36.0                            33.4
# 6                     38.0                            43.5
# 7                     37.5                            23.4
# 8                      NaN                             NaN
# 9                     46.1                            16.8
# 10                    20.4                            18.0
# 11                   100.0                            13.0
# 12                    24.8                            14.3
# 13                    34.8                            31.1
# 14                    20.6                             8.5
# 15                    39.2                            29.2
# 16                    36.4                            37.3
# 17                    35.7                            18.8
# 18                    30.7                            25.0
# 19                    34.6                            18.4
# 20                    37.5                            15.8
# 21                    18.7                            12.9
# 22                    25.3                             7.2
# 23                    29.9                            36.6
# 24                    53.6                            12.9
# 25                    36.4                            37.3
# 26                    28.4                            39.1
# 27                     NaN                             NaN
# 28                    36.5                            24.7
# 29                    21.3                             8.6
# 30                     NaN                             NaN
# 31                    18.9                            13.6
# 32                     NaN                             NaN
# 33                    80.2                             7.1
# 34                     NaN                             NaN
# 35                    76.9                            16.0
# 36                    72.7                            17.5
# 37                     NaN                             NaN
# 38                     NaN                             NaN
# 39                     NaN                             NaN
# 40                    22.9                             5.4
# 41                     NaN                             NaN
# 42                    34.0                            16.6
# 43                    36.4                            37.3
# 44                     NaN                             NaN
# 45                    36.4                            37.3
# 46                     NaN                             NaN
# 47                     NaN                             NaN
# 48                     NaN                             NaN
# 49                     NaN                             NaN
#
#     Traffic Commute Time Index  Pollution Index  Climate Index  \
# 0                         42.5             42.0           85.3
# 1                         53.1             84.7           63.8
# 2                         57.9             90.3           58.9
# 3                         45.7             74.7           70.6
# 4                         55.0             83.5           71.5
# 5                         51.7             89.8           61.2
# 6                         47.8             71.5           83.6
# 7                         50.8             79.0           99.0
# 8                          NaN              NaN            NaN
# 9                         53.1             81.5           92.4
# 10                        49.9             90.8           88.5
# 11                        43.6             58.3           79.7
# 12                        61.4             94.2           71.3
# 13                        43.6             77.9           57.6
# 14                        59.6             78.4           60.9
# 15                        45.6             77.9           58.4
# 16                        45.7             74.7           70.6
# 17                        50.4             55.2           55.8
# 18                        49.8             51.8           98.3
# 19                        68.8             89.0           60.8
# 20                        51.4             68.2           93.0
# 21                        42.5             89.3           71.3
# 22                        53.5             83.1           89.4
# 23                        31.9             92.5           63.4
# 24                        42.5             42.0           85.3
# 25                        45.7             74.7           70.6
# 26                        51.8             80.4           71.0
# 27                         NaN              NaN            NaN
# 28                        51.8             67.3           88.2
# 29                        46.7             74.7           53.2
# 30                         NaN              NaN            NaN
# 31                        34.7             78.7           67.6
# 32                         NaN              NaN            NaN
# 33                        57.5             67.4           95.5
# 34                         NaN              NaN            NaN
# 35                        44.7             57.9           88.3
# 36                        41.3             64.8           88.4
# 37                         NaN              NaN            NaN
# 38                         NaN              NaN            NaN
# 39                         NaN              NaN            NaN
# 40                        42.4             76.1           73.5
# 41                         NaN              NaN            NaN
# 42                        50.4             85.3           97.7
# 43                        45.7             74.7           70.6
# 44                         NaN              NaN            NaN
# 45                        45.7             74.7           70.6
# 46                         NaN              NaN            NaN
# 47                         NaN              NaN            NaN
# 48                         NaN              NaN            NaN
# 49                         NaN              NaN            NaN
#
#           Country_y            City_y
# 0             Japan             Tokyo
# 1         Indonesia           Jakarta
# 2             India             Delhi
# 3             China         Guangzhou
# 4             India            Mumbai
# 5       Philippines            Manila
# 6             China          Shanghai
# 7            Brazil         Sao Paulo
# 8               NaN               NaN
# 9            Mexico       Mexico City
# 10            Egypt             Cairo
# 11    United States          New York
# 12       Bangladesh             Dhaka
# 13            China           Beijing
# 14            India           Kolkata
# 15         Thailand           Bangkok
# 16            China          Shenzhen
# 17           Russia            Moscow
# 18        Argentina      Buenos Aires
# 19          Nigeria             Lagos
# 20           Turkey          Istanbul
# 21         Pakistan           Karachi
# 22            India         Bangalore
# 23          Vietnam  Ho Chi Minh City
# 24            Japan             Osaka
# 25            China           Chengdu
# 26             Iran            Tehran
# 27              NaN               NaN
# 28           Brazil    Rio de Janeiro
# 29            India           Chennai
# 30              NaN               NaN
# 31         Pakistan            Lahore
# 32              NaN               NaN
# 33    United States       Los Angeles
# 34              NaN               NaN
# 35   United Kingdom            London
# 36           France             Paris
# 37              NaN               NaN
# 38              NaN               NaN
# 39              NaN               NaN
# 40            India         Hyderabad
# 41              NaN               NaN
# 42             Peru              Lima
# 43            China             Wuhan
# 44              NaN               NaN
# 45            China          Hangzhou
# 46              NaN               NaN
# 47              NaN               NaN
# 48              NaN               NaN
# 49              NaN               NaN
#
# [50 rows x 37 columns]

# %%
merged_cities_df.shape
# Out:
# (47902, 37)

# %%
# merged_cities_1000_df.to_csv("/content/drive/MyDrive/Colab Notebooks/DE/Project/Raw_csvs/merged_cities_1000.csv", index=False)

merged_cities_df.to_csv("/content/drive/MyDrive/Colab Notebooks/DE/Project/Modified_csvs/merged_cities.csv", index=False)

# %% [markdown]
# # Filling the missing data in the merged cities

# %%
# prompt: in merged_cities_df, if numeric data, replace the NaN's with the average of numeric values of the same columns who share a similar Country_x, change the data frame name to merged_cities_ filled_df

# Create a copy of the dataframe
merged_cities_filled_df = merged_cities_df.copy()

# Select numeric columns
numeric_columns = merged_cities_filled_df.select_dtypes(include=['float64', 'int64']).columns

# Group the dataframe by Country_x and calculate the mean for each numeric column
country_means = merged_cities_filled_df.groupby('Country_x')[numeric_columns].mean().round(1)

# Replace NaN values in the numeric columns with the corresponding country mean
for col in numeric_columns:
    for country in country_means.index:
        merged_cities_filled_df.loc[(merged_cities_filled_df['Country_x'] == country) & (merged_cities_filled_df[col].isna()), col] = country_means.loc[country, col]

# Display the first few rows of the dataframe
merged_cities_filled_df.head()
# Out:
#       City_x  Country_x      Lat       Lng iso2 iso3  Population  \
# 0      Tokyo      Japan  35.6897  139.6922   JP  JPN  37732000.0
# 1    Jakarta  Indonesia  -6.1750  106.8275   ID  IDN  33756000.0
# 2      Delhi      India  28.6100   77.2300   IN  IND  32226000.0
# 3  Guangzhou      China  23.1300  113.2600   CN  CHN  26940000.0
# 4     Mumbai      India  19.0761   72.8775   IN  IND  24973000.0
#
#              ID       City, Country  Rank_x  ... Purchasing Power Index  \
# 0  1.392686e+09        Tokyo, Japan   169.0  ...                  111.2
# 1  1.360771e+09  Jakarta, Indonesia   312.0  ...                   43.4
# 2  1.356873e+09        Delhi, India   354.0  ...                  118.8
# 3  1.156237e+09    Guangzhou, China   285.0  ...                   90.2
# 4  1.356227e+09       Mumbai, India   351.0  ...                   70.2
#
#    Safety Index  Health Care Index  Cost of Living Index_y  \
# 0          76.0               79.2                    53.6
# 1          47.3               56.9                    30.0
# 2          41.0               66.7                    23.4
# 3          72.5               66.6                    36.4
# 4          55.3               65.3                    23.8
#
#    Property Price to Income Ratio  Traffic Commute Time Index  \
# 0                            12.9                        42.5
# 1                            15.8                        53.1
# 2                             8.8                        57.9
# 3                            37.3                        45.7
# 4                            32.6                        55.0
#
#    Pollution Index  Climate Index   Country_y     City_y
# 0             42.0           85.3       Japan      Tokyo
# 1             84.7           63.8   Indonesia    Jakarta
# 2             90.3           58.9       India      Delhi
# 3             74.7           70.6       China  Guangzhou
# 4             83.5           71.5       India     Mumbai
#
# [5 rows x 37 columns]

# %%
merged_cities_filled_df.to_csv("/content/drive/MyDrive/Colab Notebooks/DE/Project/Modified_csvs/merged_cities_filled.csv", index=False)

# merged_cities_filled_df.to_csv(r"C:\Users\paude\Documents\00. Backup 2023\EXTERIOR\MASTER\MA IAAC\03. Cursada\01. Modulo 03\S01 DE\Class Project\DE_Team\Modified_csvs\123.csv", index=False)
